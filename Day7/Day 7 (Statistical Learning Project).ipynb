# %% [markdown]
# # Assignment     -   Attrition

# %% [markdown]
# <font color=red>__Step 1 - Launching__</font>

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
dataset=pd.read_csv('general_data.csv')
dataset.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 1   31       Yes  Travel_Frequently  Research & Development                10
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 1          1  Life Sciences              1           2  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
dataset.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
dataset
# Out:
#       Age Attrition     BusinessTravel              Department  \
# 0      51        No      Travel_Rarely                   Sales
# 1      31       Yes  Travel_Frequently  Research & Development
# 2      32        No  Travel_Frequently  Research & Development
# 3      38        No         Non-Travel  Research & Development
# 4      32        No      Travel_Rarely  Research & Development
# ...   ...       ...                ...                     ...
# 4405   42        No      Travel_Rarely  Research & Development
# 4406   29        No      Travel_Rarely  Research & Development
# 4407   25        No      Travel_Rarely  Research & Development
# 4408   42        No      Travel_Rarely                   Sales
# 4409   40        No      Travel_Rarely  Research & Development
#
#       DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 0                    6          2  Life Sciences              1           1
# ...

# %% [markdown]
# <font color=red>__Step 2 - Data Treatment__</font>

# %%
dataset.isnull()
# Out:
#         Age  Attrition  BusinessTravel  Department  DistanceFromHome  \
# 0     False      False           False       False             False
# 1     False      False           False       False             False
# 2     False      False           False       False             False
# 3     False      False           False       False             False
# 4     False      False           False       False             False
# ...     ...        ...             ...         ...               ...
# 4405  False      False           False       False             False
# 4406  False      False           False       False             False
# 4407  False      False           False       False             False
# 4408  False      False           False       False             False
# 4409  False      False           False       False             False
#
#       Education  EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# ...

# %%
dataset.duplicated()
# Out:
# 0       False
# 1       False
# 2       False
# 3       False
# 4       False
#         ...
# 4405    False
# 4406    False
# 4407    False
# 4408    False
# 4409    False
# Length: 4410, dtype: bool

# %% [markdown]
# <font color=red>__Step 3 – Univariate Analysis:__</font>

# %%
dataset2=dataset[['Age','DistanceFromHome','Education','MonthlyIncome',
'NumCompaniesWorked', 'PercentSalaryHike','StockOptionLevel','TotalWorkingYears', 'TrainingTimesLastYear',
'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].describe()
dataset2
# Out:
#                Age  DistanceFromHome    Education  MonthlyIncome  \
# count  4410.000000       4410.000000  4410.000000    4410.000000
# mean     36.923810          9.192517     2.912925   65029.312925
# std       9.133301          8.105026     1.023933   47068.888559
# min      18.000000          1.000000     1.000000   10090.000000
# 25%      30.000000          2.000000     2.000000   29110.000000
# 50%      36.000000          7.000000     3.000000   49190.000000
# 75%      43.000000         14.000000     4.000000   83800.000000
# max      60.000000         29.000000     5.000000  199990.000000
#
#        NumCompaniesWorked  PercentSalaryHike  StockOptionLevel  \
# count         4391.000000        4410.000000       4410.000000
# mean             2.694830          15.209524          0.793878
# std              2.498887           3.659108          0.851883
# min              0.000000          11.000000          0.000000
# ...

# %%
dataset2=dataset[['Age','DistanceFromHome','Education','MonthlyIncome',
'NumCompaniesWorked', 'PercentSalaryHike','StockOptionLevel','TotalWorkingYears', 'TrainingTimesLastYear',
'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].median()
dataset2
# Out:
# Age                           36.0
# DistanceFromHome               7.0
# Education                      3.0
# MonthlyIncome              49190.0
# NumCompaniesWorked             2.0
# PercentSalaryHike             14.0
# StockOptionLevel               1.0
# TotalWorkingYears             10.0
# TrainingTimesLastYear          3.0
# YearsAtCompany                 5.0
# YearsSinceLastPromotion        1.0
# YearsWithCurrManager           3.0
# dtype: float64

# %%
dataset2=dataset[['Age','DistanceFromHome','Education','MonthlyIncome',
'NumCompaniesWorked', 'PercentSalaryHike','StockOptionLevel','TotalWorkingYears', 'TrainingTimesLastYear',
'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].mode()
dataset2
# Out:
#    Age  DistanceFromHome  Education  MonthlyIncome  NumCompaniesWorked  \
# 0   35                 2          3          23420                 1.0
#
#    PercentSalaryHike  StockOptionLevel  TotalWorkingYears  \
# 0                 11                 0               10.0
#
#    TrainingTimesLastYear  YearsAtCompany  YearsSinceLastPromotion  \
# 0                      2               5                        0
#
#    YearsWithCurrManager
# 0                     2

# %%
dataset2=dataset[['Age','DistanceFromHome','Education','MonthlyIncome',
'NumCompaniesWorked', 'PercentSalaryHike','StockOptionLevel','TotalWorkingYears', 'TrainingTimesLastYear',
'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].var()
dataset2
# Out:
# Age                        8.341719e+01
# DistanceFromHome           6.569144e+01
# Education                  1.048438e+00
# MonthlyIncome              2.215480e+09
# NumCompaniesWorked         6.244436e+00
# PercentSalaryHike          1.338907e+01
# StockOptionLevel           7.257053e-01
# TotalWorkingYears          6.056298e+01
# TrainingTimesLastYear      1.661465e+00
# YearsAtCompany             3.751728e+01
# YearsSinceLastPromotion    1.037935e+01
# YearsWithCurrManager       1.272582e+01
# dtype: float64

# %%
dataset2=dataset[['Age','DistanceFromHome','Education','MonthlyIncome',
'NumCompaniesWorked', 'PercentSalaryHike','StockOptionLevel','TotalWorkingYears', 'TrainingTimesLastYear',
'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].skew()
dataset2
# Out:
# Age                        0.413005
# DistanceFromHome           0.957466
# Education                 -0.289484
# MonthlyIncome              1.368884
# NumCompaniesWorked         1.026767
# PercentSalaryHike          0.820569
# StockOptionLevel           0.968321
# TotalWorkingYears          1.116832
# TrainingTimesLastYear      0.552748
# YearsAtCompany             1.763328
# YearsSinceLastPromotion    1.982939
# YearsWithCurrManager       0.832884
# dtype: float64

# %%
dataset2=dataset[['Age','DistanceFromHome','Education','MonthlyIncome',
'NumCompaniesWorked', 'PercentSalaryHike','StockOptionLevel','TotalWorkingYears', 'TrainingTimesLastYear',
'YearsAtCompany','YearsSinceLastPromotion', 'YearsWithCurrManager']].kurt()
dataset2
# Out:
# Age                       -0.405951
# DistanceFromHome          -0.227045
# Education                 -0.560569
# MonthlyIncome              1.000232
# NumCompaniesWorked         0.007287
# PercentSalaryHike         -0.302638
# StockOptionLevel           0.361086
# TotalWorkingYears          0.912936
# TrainingTimesLastYear      0.491149
# YearsAtCompany             3.923864
# YearsSinceLastPromotion    3.601761
# YearsWithCurrManager       0.167949
# dtype: float64

# %% [markdown]
# ![Screenshot%20%2851%29.png](attachment:Screenshot%20%2851%29.png)

# %% [markdown]
# Inference from the analysis:
#
#  -  All the above variables show positive skewness; while Age & Mean_distance_from_home
# are leptokurtic and all other variables are platykurtic.
#
#  -  The Mean_Monthly_Income’s IQR is at 54K suggesting company wide attrition across all
# income bands.
#
#  - Mean age forms a near normal distribution with 13 years of IQR.
#
#  - There is maximum variation Mean Age with 8314 years.
#
#  - The Mean Years Since Last Promotion is most consistent variable with 3.22 years of standard deviation.

# %% [markdown]
# <font color=blue>Outliers:</font>

# %%
import matplotlib.pyplot as plt
plt.scatter(dataset.Attrition,dataset.Age)

# %%
import matplotlib.pyplot as plt
plt.scatter(dataset.Attrition,dataset.DistanceFromHome)

# %%
import matplotlib.pyplot as plt
plt.scatter(dataset.Attrition,dataset.MonthlyIncome)

# %%
import matplotlib.pyplot as plt
plt.scatter(dataset.Attrition,dataset.TotalWorkingYears)

# %%
import matplotlib.pyplot as plt
plt.scatter(dataset.Attrition,dataset.YearsAtCompany)

# %%
import matplotlib.pyplot as plt
plt.scatter(dataset.Attrition,dataset.YearsSinceLastPromotion)

# %%
import matplotlib.pyplot as plt
plt.scatter(dataset.Attrition,dataset.YearsWithCurrManager)

# %% [markdown]
# There’s no regression found while plotting Age, MonthlyIncome, TotalWorkingYears,
# YearsAtCompany, etc., on a scatter plot.

# %%
box_plot=dataset.Age
plt.boxplot(box_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2aad79bb908>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2aad79d1e08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2aad79cc248>],
#  'medians': [<matplotlib.lines.Line2D at 0x2aad79d6b48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2aad79d6c48>],
#  'means': []}

# %% [markdown]
# Age is normally distributed without any outliers.

# %%
box_plot=dataset.MonthlyIncome
plt.boxplot(box_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2aad8a07708>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2aad8a07fc8>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2aad8a03d08>],
#  'medians': [<matplotlib.lines.Line2D at 0x2aad8a0df48>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2aad8a11dc8>],
#  'means': []}

# %% [markdown]
# Monthly Income is Right skewed with several outliers.

# %%
box_plot=dataset.YearsAtCompany
plt.boxplot(box_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2aad8a76d88>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2aad8a79d48>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2aad8a76308>],
#  'medians': [<matplotlib.lines.Line2D at 0x2aad8a7ecc8>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2aad8a7edc8>],
#  'means': []}

# %% [markdown]
# Years at company is also Right Skewed with several outliers observed.

# %%
box_plot=dataset.YearsSinceLastPromotion
plt.boxplot(box_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2aad8ae5d08>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2aad8ae8c88>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2aad8ae5308>],
#  'medians': [<matplotlib.lines.Line2D at 0x2aad8aedd88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2aad8aede88>],
#  'means': []}

# %% [markdown]
# Years since last promotion is also Right Skewed with several outliers observed.

# %%
box_plot=dataset.YearsWithCurrManager
plt.boxplot(box_plot)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x2aad8b50648>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x2aad8b50f08>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x2aad8b4cc48>],
#  'medians': [<matplotlib.lines.Line2D at 0x2aad8b57e88>],
#  'fliers': [<matplotlib.lines.Line2D at 0x2aad8b5cd08>],
#  'means': []}

# %% [markdown]
# Years with current manager is also Right Skewed with several outliers observed.

# %% [markdown]
# <font color=red>__Step 4 – Visualisation:__</font>

# %% [markdown]
# __Bar Graph__

# %%
import matplotlib.pyplot as plt 
plt.bar(dataset.Attrition,dataset.Age,label='Age')
plt.legend(loc='upper right')
plt.title("Attrition vs Age")
plt.show()
plt.bar(dataset.Attrition,dataset.DistanceFromHome,label='DistanceFromHome')
plt.legend(loc='upper right')
plt.title("Attrition vs Distance From Home")
plt.show()
plt.bar(dataset.Attrition,dataset.MonthlyIncome,label='Monthly Income')
plt.legend(loc='upper right')
plt.title("Attrition vs Monthly Income")
plt.show()
plt.bar(dataset.Attrition,dataset.TotalWorkingYears,label='Total Working years')
plt.legend(loc='upper right')
plt.title("Attrition vs Total Working Years")
plt.show()
plt.bar(dataset.Attrition,dataset.YearsSinceLastPromotion,label='Years Since Last Promotion')
plt.legend(loc='upper right')
plt.title("Attrition vs Years Since Last Promotion")
plt.show()
plt.bar(dataset.Attrition,dataset.YearsAtCompany,label='YearsAtCompany')
plt.legend(loc='upper right')
plt.title("Attrition vs Years At Company")
plt.show()
plt.bar(dataset.Attrition,dataset.YearsWithCurrManager,label='Years With Currmanager')
plt.legend(loc='upper right')
plt.title("Attrition vs Years With CurrManager")
plt.show()

# %%
dataset1=dataset[["Attrition","DistanceFromHome","MonthlyIncome","TotalWorkingYears","YearsAtCompany","YearsWithCurrManager"]]
dataset1.head()
# Out:
#   Attrition  DistanceFromHome  MonthlyIncome  TotalWorkingYears  \
# 0        No                 6         131160                1.0
# 1       Yes                10          41890                6.0
# 2        No                17         193280                5.0
# 3        No                 2          83210               13.0
# 4        No                10          23420                9.0
#
#    YearsAtCompany  YearsWithCurrManager
# 0               1                     0
# 1               5                     4
# 2               5                     3
# 3               8                     5
# 4               6                     4

# %%
import seaborn as sns
sns.pairplot(dataset1)
plt.show()

# %%
Attrition_Yes=dataset1[dataset1["Attrition"]=='Yes']
Attrition_Yes.head()
# Out:
#    Attrition  DistanceFromHome  MonthlyIncome  TotalWorkingYears  \
# 1        Yes                10          41890                6.0
# 6        Yes                11          58130                5.0
# 13       Yes                 1          57620               10.0
# 28       Yes                 1         103330               19.0
# 30       Yes                 4          68540                5.0
#
#     YearsAtCompany  YearsWithCurrManager
# 1                5                     4
# 6                0                     0
# 13              10                     9
# 28               1                     0
# 30               3                     2

# %%
sns.pairplot(Attrition_Yes)
plt.show()

# %%
Attrition_No=dataset1[dataset1["Attrition"]=='No']
Attrition_No.head()
# Out:
#   Attrition  DistanceFromHome  MonthlyIncome  TotalWorkingYears  \
# 0        No                 6         131160                1.0
# 2        No                17         193280                5.0
# 3        No                 2          83210               13.0
# 4        No                10          23420                9.0
# 5        No                 8          40710               28.0
#
#    YearsAtCompany  YearsWithCurrManager
# 0               1                     0
# 2               5                     3
# 3               8                     5
# 4               6                     4
# 5               7                     7

# %%
sns.pairplot(Attrition_No)
plt.show()

# %% [markdown]
# <font color=red>__Step 5 – Statistical Tests (Mann-Whitney)__</font>

# %%
Attrition_Yes=dataset[dataset["Attrition"]=='Yes']
Attrition_Yes.head()
# Out:
#     Age Attrition     BusinessTravel              Department  \
# 1    31       Yes  Travel_Frequently  Research & Development
# 6    28       Yes      Travel_Rarely  Research & Development
# 13   47       Yes         Non-Travel  Research & Development
# 28   44       Yes  Travel_Frequently  Research & Development
# 30   26       Yes      Travel_Rarely  Research & Development
#
#     DistanceFromHome  Education EducationField  EmployeeCount  EmployeeID  \
# 1                 10          1  Life Sciences              1           2
# 6                 11          2        Medical              1           7
# 13                 1          1        Medical              1          14
# 28                 1          2        Medical              1          29
# 30                 4          3        Medical              1          31
#
#     Gender  ...  NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
Attrition_Yes.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %%
Attrition_No=dataset[dataset["Attrition"]=='No']
Attrition_No.head()
# Out:
#    Age Attrition     BusinessTravel              Department  DistanceFromHome  \
# 0   51        No      Travel_Rarely                   Sales                 6
# 2   32        No  Travel_Frequently  Research & Development                17
# 3   38        No         Non-Travel  Research & Development                 2
# 4   32        No      Travel_Rarely  Research & Development                10
# 5   46        No      Travel_Rarely  Research & Development                 8
#
#    Education EducationField  EmployeeCount  EmployeeID  Gender  ...  \
# 0          2  Life Sciences              1           1  Female  ...
# 2          4          Other              1           3    Male  ...
# 3          5  Life Sciences              1           4    Male  ...
# 4          1        Medical              1           5    Male  ...
# 5          3  Life Sciences              1           6  Female  ...
#
#    NumCompaniesWorked Over18 PercentSalaryHike  StandardHours  \
# ...

# %%
Attrition_No.columns
# Out:
# Index(['Age', 'Attrition', 'BusinessTravel', 'Department', 'DistanceFromHome',
#        'Education', 'EducationField', 'EmployeeCount', 'EmployeeID', 'Gender',
#        'JobLevel', 'JobRole', 'MaritalStatus', 'MonthlyIncome',
#        'NumCompaniesWorked', 'Over18', 'PercentSalaryHike', 'StandardHours',
#        'StockOptionLevel', 'TotalWorkingYears', 'TrainingTimesLastYear',
#        'YearsAtCompany', 'YearsSinceLastPromotion', 'YearsWithCurrManager'],
#       dtype='object')

# %% [markdown]
# __Attrition vs Distance From Home__

# %%
from scipy.stats import mannwhitneyu 
stat, p=mannwhitneyu(Attrition_Yes.DistanceFromHome,Attrition_No.DistanceFromHome)
print(stat, p)
# Out:
# 1312110.0 0.4629185205822659

# %% [markdown]
# <font color="Blue">As the P value is > 0.05, the H0 is accepted and Ha is rejected.
#
# H0: There is no significant differences in the Distance From Home between attrition (Y) and attirition
# (N)
#
# Ha: There is significant differences in the Distance From Home between attrition (Y) and attirition (N)</font>

# %% [markdown]
# __Attrition vs Monthly Income__

# %%
stat, p=mannwhitneyu(Attrition_Yes.MonthlyIncome,Attrition_No.MonthlyIncome)
print(stat, p)
# Out:
# 1264900.5 0.053577283839938566

# %% [markdown]
# <font color="Blue">As the P value is > than 0.05, the H0 is accepted  and ha is rejected.
#
#
# H0: There is no significant differences in the Total Working Years between attrition (Y) and attirition
# (N)
#
# Ha: There is significant differences in the Total Working Years between attrition (Y) and attirition (N)</font>

# %% [markdown]
# __Attrition vs Total Working Years__

# %%
stat, p=mannwhitneyu(Attrition_Yes.TotalWorkingYears,Attrition_No.TotalWorkingYears)
print(stat, p)
# Out:
# 909954.0 2.8897554531400447e-39

# %% [markdown]
# <font color="Blue">As the P value is < than 0.05, the H0 is rejected and ha is accepted.
#
#
# H0: There is no significant differences in the Total Working Years between attrition (Y) and attirition
# (N)
#
# Ha: There is significant differences in the Total Working Years between attrition (Y) and attirition (N)</font>

# %% [markdown]
# __Attrition vs Years At Company__

# %%
stat, p=mannwhitneyu(Attrition_Yes.YearsAtCompany,Attrition_No.YearsAtCompany)
print(stat, p)
# Out:
# 923238.0 6.047598261692858e-37

# %% [markdown]
# <font color="Blue">As the P value is again < than 0.05, the H0 is rejected and ha is accepted.
#
#
# H0: There is no significant differences in the Years At Company between attrition (Y) and attirition
# (N)
#
# Ha: There is significant differences in the Years At Company between attrition (Y) and attirition (N)</font>

# %% [markdown]
# __Attrition vs Years with current Manager__

# %%
stat, p=mannwhitneyu(Attrition_Yes.YearsWithCurrManager,Attrition_No.YearsWithCurrManager)
print(stat, p)
# Out:
# 957253.5 1.2365483142169853e-31

# %% [markdown]
# <font color="Blue">As the P value is again < than 0.05, the H0 is rejected and ha is accepted.
#
#
# H0: There is no significant differences in the Years With Current Manager between attrition (Y) and
# attirition (N)
#
#
# Ha: There is significant differences in the Years With Current Manager between attrition (Y) and
# attirition (N)</font>

# %% [markdown]
# <font color=red>__Step 5 – Statistical Tests (Separate T Test)__</font>

# %% [markdown]
# __Attrition vs Distance from Home__

# %%
from scipy.stats import ttest_ind
stat, p=ttest_ind(Attrition_No.DistanceFromHome,Attrition_Yes.DistanceFromHome)
print(stat, p)
# Out:
# 0.6460416038042738 0.518286042805572

# %% [markdown]
# <font color="Violet">As the P value is > 0.05, the H0 is accepted and Ha is rejected.
#
# H0: There is no significant differences in the Distance From Home between attrition (Y) and attirition
# (N)
#
# Ha: There is significant differences in the Distance From Home between attrition (Y) and attirition (N)</font>

# %% [markdown]
# __Attrition vs Monthly Income__

# %%
stat, p=ttest_ind(Attrition_No.MonthlyIncome,Attrition_Yes.MonthlyIncome)
print(stat, p)
# Out:
# 2.0708863763619316 0.03842748490605113

# %% [markdown]
# <font color="Violet">As the P value is < than 0.05, the H0 is rejected  and ha is accepted.
#
#
# H0: There is no significant differences in the Total Working Years between attrition (Y) and attirition
# (N)
#
# Ha: There is significant differences in the Total Working Years between attrition (Y) and attirition (N)</font>

# %% [markdown]
# __Attrition vs Years At Company__

# %%
stat, p=ttest_ind(Attrition_No.YearsAtCompany,Attrition_Yes.YearsAtCompany)
print(stat, p)
# Out:
# 9.004357011787226 3.163883122491456e-19

# %% [markdown]
# <font color="Violet">As the P value is again < than 0.05, the H0 is rejected and ha is accepted.
#
#
# H0: There is no significant differences in the Years At Company between attrition (Y) and attirition
# (N)
#
# Ha: There is significant differences in the Years At Company between attrition (Y) and attirition (N)</font>

# %% [markdown]
# __Attrition vs Years with Current Manager__

# %%
stat, p=ttest_ind(Attrition_No.YearsWithCurrManager,Attrition_Yes.YearsWithCurrManager)
print(stat, p)
# Out:
# 10.499379408703438 1.7339322652918153e-25

# %% [markdown]
# <font color="Violet">As the P value is again < than 0.05, the H0 is rejected and ha is accepted.
#
#
# H0: There is no significant differences in the Years With Current Manager between attrition (Y) and
# attirition (N)
#
#
# Ha: There is significant differences in the Years With Current Manager between attrition (Y) and
# attirition (N)</font>

# %% [markdown]
# <font color=red>__Step 7 – Unsupervised Learning - Correlation Analysis__</font>

# %% [markdown]
# In order to find the interdependency of the variables DistanceFromHome, MonthlyIncome, Age ,TotalWorkingYears, YearsAtCompany, Years Since Last Promotion, YearsWithCurrManager from that of Attrition, we executed the Correlation Analysis as follows:

# %%
from scipy.stats import pearsonr
dataset['TotalWorkingYears']=dataset['TotalWorkingYears'].fillna(11.28)

# %% [markdown]
# __Attrition & Distance From Home__

# %%
from sklearn import preprocessing
Label_encoder=preprocessing.LabelBinarizer()
dataset["Attrition"]=Label_encoder.fit_transform(dataset["Attrition"])
stats, p=pearsonr(dataset.Attrition, dataset.DistanceFromHome)
print(stats, p)
# Out:
# -0.009730141010179435 0.5182860428049617

# %% [markdown]
# <font color=green>___H0-There is no significant corelation between Attrition and Distance from home.___
#
# ___Ha-There is significant corelation between Attrition and Distance from home.___
# </font>
#
#
#
# As r = -0.009, there’s low negative correlation between Attrition and DistanceFromHome.
# As the P value of 0.518 is > 0.05, we are accepting H0 and hence there’s no significant correlation
# between Attrition & DistanceFromHome.

# %% [markdown]
# __Attrition & Monthly Income__

# %%
stats, p=pearsonr(dataset.Attrition, dataset.MonthlyIncome)
print(stats,p)
# Out:
# -0.031176281698114025 0.0384274849060192

# %% [markdown]
# <font color=green>___H0-There is no significant corelation between Attrition and Monthly Income.___
#
# ___Ha-There is significant corelation between Attrition and Monthly Income.___</font>
#
#
#
# As r = -0.031, there’s low negative correlation between Attrition and MonthlyIncome.
# As the P value of 0.038 is < 0.05, we are accepting Ha and hence there’s significant correlation
# between Attrition & MonthlyIncome.

# %% [markdown]
# __Attrition & Age__

# %%
from scipy.stats import pearsonr
stats,p=pearsonr(dataset.Attrition,dataset.Age)
print(stats,p)
# Out:
# -0.159205006865775 1.996801615893625e-26

# %% [markdown]
# <font color=green>___H0-There  is no significant difference between Attrition and Age.___
#
# ___Ha-There  is significant difference between Attrition and Age.___</font>
#
#
#
# As r = -0.1592, there’s low negative correlation between Attrition and Age.
# As the P value is < 0.05, we are accepting Ha and hence there’s significant correlation between
# Attrition & Age.

# %% [markdown]
# __Attrition & Total Working Years__

# %%
stats,p=pearsonr(dataset.Attrition,dataset.TotalWorkingYears)
print(stats,p)
# Out:
# -0.17011136355964646 5.4731597518148054e-30

# %% [markdown]
# <font color=green>___H0-There is no significant corelation between Attrition and Total Working Years.___
#
# ___Ha-There is significant corelation between Attrition and Total Working Years.___</font>
#
#
#
# As r = -0.17, there’s low negative correlation between Attrition and TotalWorkingYears.
# As the P value is < 0.05, we are accepting Ha and hence there’s significant correlation between
# Attrition & TotalWorkingYears.

# %% [markdown]
# __Attrition & Years at Company__

# %%
stats,p=pearsonr(dataset.Attrition,dataset.YearsAtCompany)
print(stats,p)
# Out:
# -0.13439221398997386 3.163883122493571e-19

# %% [markdown]
# <font color=green>___H0-There is no significant corelation between Attrition and Years at Company.___
#
# ___Ha-There is significant corelation between Attrition and Years at Company.___</font>
#
#
#
# As r = -0.1343, there’s low negative correlation between Attrition and YearsAtCompany.
# As the P value is < 0.05, we are accepting Ha and hence there’s significant correlation between
# Attrition & YearsAtCompany.

# %% [markdown]
# __Attrition & Years Since Last Promotion__

# %%
stats,p=pearsonr(dataset.Attrition,dataset.YearsSinceLastPromotion)
print(stats,p)
# Out:
# -0.03301877514258329 0.02833033618939086

# %% [markdown]
# <font color=green>___H0-There is no signifiant corelatio between Attrition and Years since Last Promotion.___
#
# ___Ha-There is signifiant corelatio between Attrition and Years since Last Promotion.___</font>
#
#
#
# As r = -0.033, there’s low negative correlation between Attrition and YearsSinceLastPromotion.
# As the P value is < 0.05, we are accepting Ha and hence there’s significant correlation between
# Attrition & YearsSinceLastPromotion.

# %% [markdown]
# __Attrition & Years with CurrManager__

# %%
stats,p=pearsonr(dataset.Attrition,dataset.YearsWithCurrManager)
print(stats,p)
# Out:
# -0.1561993159016244 1.7339322652951965e-25

# %% [markdown]
# <font color=green>___H0-There is no significant corelation between Attrition and Years with CurrManager.___
#
# ___H0-There is significant corelation between Attrition and Years with CurrManager.___</font>
#
#
#
# As r = -0.1561, there’s low negative correlation between Attrition and YearsWithCurrManager.
# As the P value is < 0.05, we are accepting Ha and hence there’s significant correlation between
# Attrition & YearsWithCurrManager.
